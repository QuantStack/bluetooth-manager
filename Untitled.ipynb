# %% [markdown]
# <table >
#     <tr><th >Stretch/Untouched <th><th> ProbDistribution <th><th> Accuracy <tr><tr>
#     <tr><td> Stretched <td><td> Gaussian <td><td> .843 <td><tr>
#     <tr><td> Stretched <td><td> Test <td><td> .927 <td><tr>
#         <tr><td> Stretched <td><td> Test <td><td> .927 <td><tr>
#             <tr><td> Stretched <td><td> Test <td><td> .927 <td><tr>
# <table>
